# %% [markdown]
# <h2>Final Project: Identifying Trump's Tweets</h2>

# %% [markdown]
# <center>
# <img src="white_house.jpg"/>
# </center>

# %% [markdown]
# <h3>Introduction</h3>
#
# <p>The goal is to classify the device that Trump uses to write each tweet with. It's been hypothesized that President Trump tweets only from his android phone and that someone else (his staff) tweets from his account using an iPhone. Analyze the text of the tweet as well as other contextual information to predict where each tweet came from. </p>

# %% [markdown]
# <h3>Rules</h3>
#
# <p> Rules of the competition: You may use any techniques you've learned in class including any open source implementations in packages such as scikit-learn, tensorflow, or pre-trained models. If you use any open source implementations, <b>please cite them in your comments</b>. The sharing of personal code between teams is strictly not allowed. Additionally obtaining a copy of the labeled test set through any means is expressly forbidden. </p>
#
# <p><b>NOTE: You are only allowed 10 submissions for this project. Please use them carefully. We will use your 10th and final submission (not be the best one) for grading.</b></p>

# %% [markdown]
# <h3>Grading</h3>
#
# <p>There are two baselines we have implemented. <code>Baseline 1 = 0.7</code> and <code>Baseline 2 = 0.82</code>. If you beat the first baseline, you will 90 points. If you beat the second baseline, you'll get 100 points.</p>
# <p>The top 30 teams on the leaderboard will receive an extra 5 bonus points.</p>

# %% [markdown]
# ### To do (added by Martin)
#
# Implement multiple learning algorithms.
#
# Implement k-fold cross validation.
#
# Optimize functions.
#
# Feature ideas:
# - Average number of words per sentence
# - Average word length
# - Number of punctuation symbols
# - Sentiment analysis
# - Day of the week
# - time of the day
# - number of capital letters
#
# ### What has been done
#
# Implemented features:
# - Number of sentences per tweet
# - Numbers of characters per tweet
# - Number of characters per sentence
#
# Implemented sklearn's SVM as learning algorithm.

# %%
#<GRADED>
import numpy as np
import pandas as pd
from sklearn import svm
#</GRADED>

## include your imports as necessary and cite open-source implementations appropriately

# %%
def read_files(train_file):
    """
    Output:
    df_X : pandas data frame of training data
    Y    : numpy array of labels
    """
    df = pd.read_csv(train_file, index_col=0)
    df_X = df[df.columns[0:17]]
    Y = np.array(df['label'])
        
    return df_X, Y

# %% [markdown]
# <h3> Training Data </h3>
#
# <p> Take a look at the file <code>train.csv</code>. Here are the first 4 tweets in the train dataset.</p>

# %%
df_X_train, Y_train = read_files('train.csv')
df_X_train[:]
# Out:
#                                                    text  favorited  \
# id
# 0     Senior United States District Judge Robert E. ...      False
# 1     Speech on Veterans' Reform:  https://t.co/XB7R...      False
# 2     Great poll- Florida! Thank you! https://t.co/4...      False
# 3     Thoughts and prayers with the victims; and the...      False
# 4     Join me in Westfield; Indiana- tomorrow night ...      False
# 5     I heard that the underachieving John King of @...      False
# 6     The media is so dishonest. If I make a stateme...      False
# 7     President Obama thinks the nation is not as di...      False
# 8     Look what is happening to our country under th...      False
# 9     New poll - thank you! #Trump2016  https://t.co...      False
# 10    Way to go @serenawilliams  - you are a true ch...      False
# 11    MAKE AMERICA SAFE AGAIN!  https://t.co/m0AJWlV...      False
# 12    Isn't it sad that on a day of national tragedy...      False
# 3             28850       NaN   7/11/2016 19:51      False         NaN
# 4             12567       NaN   7/11/2016 11:57      False         NaN
# 5             22978       NaN   7/10/2016 18:58      False         NaN
# 6             44600       NaN   7/10/2016 18:42      False         NaN
# 7             35167       NaN   7/10/2016 18:27      False         NaN
# 8             55495       NaN   7/10/2016 12:02      False         NaN
# 9             24040       NaN    7/9/2016 21:22      False         NaN
# 10            25035       NaN    7/9/2016 15:18      False         NaN
# 11            39088       NaN    7/8/2016 23:26      False         NaN
# 12            42313       NaN    7/8/2016 21:31      False         NaN
# 13            40857       NaN    7/8/2016 14:32      False         NaN
# 14            19591       NaN    7/8/2016 13:20      False         NaN
# 15            84236       NaN    7/8/2016 11:02      False         NaN
# 16            54637       NaN     7/8/2016 1:52      False         NaN
# 17            14757       NaN    7/7/2016 20:09      False         NaN
# 18            18399       NaN    7/7/2016 20:06      False         NaN
# 19            10670       NaN    7/7/2016 20:04      False         NaN
# 20            27451       NaN    7/7/2016 18:07      False         NaN
# 21            19774       NaN    7/7/2016 11:33      False         NaN
# 22            62121       NaN     7/7/2016 1:34      False         NaN
# 23            24746       NaN    7/6/2016 21:58      False         NaN
# 24            16859       NaN    7/6/2016 14:06      False         NaN
# 25            15349       NaN    7/6/2016 14:01      False         NaN
# 26            14936       NaN    7/6/2016 13:24      False         NaN
# 27            13763       NaN    7/6/2016 13:12      False         NaN
# 28            13041       NaN    7/6/2016 13:08      False         NaN
# 29            28750       NaN    7/6/2016 12:31      False         NaN
# ...             ...       ...               ...        ...         ...
# 1059           8037       NaN   1/16/2016 19:32      False         NaN
# 1060           6151       NaN   1/16/2016 18:31      False         NaN
# 1061           6172       NaN   1/16/2016 18:26      False         NaN
# 1062           5368       NaN   1/16/2016 18:23      False         NaN
# 1063           5792       NaN   1/16/2016 18:22      False         NaN
# 1064           5931       NaN   1/16/2016 18:21      False         NaN
# 1065           5555       NaN   1/16/2016 16:11      False         NaN
# 1066           8788       NaN   1/16/2016 13:42      False         NaN
# 1067           5757       NaN   1/16/2016 13:31      False         NaN
# 1068           5793       NaN    1/8/2016 23:12      False         NaN
# 1069           6311       NaN    1/8/2016 22:36      False         NaN
# 1070           7280       NaN    1/8/2016 22:09      False         NaN
# 1071           5997       NaN    1/8/2016 22:03      False         NaN
# 1072           5088       NaN    1/8/2016 21:20      False         NaN
# 1073           5439       NaN    1/8/2016 15:57      False         NaN
# 1074           3377       NaN    1/1/2016 21:29      False         NaN
# 1075           7578       NaN     1/1/2016 6:08      False         NaN
# 1076           8349       NaN     1/1/2016 6:07      False         NaN
# 1077           9248       NaN     1/1/2016 5:18      False         NaN
# 1078           8611       NaN     1/1/2016 3:25      False         NaN
# 1079           8129       NaN  12/26/2015 13:00      False         NaN
# 1080          12774       NaN  12/25/2015 21:49      False         NaN
# 1081           6174       NaN  12/25/2015 21:42      False         NaN
# 1082           3172       CNN  12/25/2015 21:11      False         NaN
# 1083           4236       NaN  12/25/2015 20:55      False         NaN
# 1084           2590       NaN   12/20/2015 8:21      False         NaN
# 1085           3550       NaN   12/20/2015 5:25      False         NaN
# 1086           3719       NaN   12/20/2015 5:11      False         NaN
# 1087           2304       NaN  12/14/2015 21:11      False         NaN
# 1088           2599       NaN  12/14/2015 20:09      False         NaN
#
#                     id.1  replyToUID  \
# id
# 0     752668000000000000         NaN
# 1     752628000000000000         NaN
# 2     752619000000000000         NaN
# 3     752591000000000000         NaN
# 4     752472000000000000         NaN
# 5     752215000000000000         NaN
# 6     752211000000000000         NaN
# 7     752208000000000000         NaN
# 8     752111000000000000         NaN
# 9     751889000000000000         NaN
# 10    751798000000000000         NaN
# 11    751558000000000000         NaN
# 12    751529000000000000         NaN
# 13    751424000000000000         NaN
# 14    751406000000000000         NaN
# 15    751371000000000000         NaN
# 16    751232000000000000         NaN
# 17    751146000000000000         NaN
# 18    751145000000000000         NaN
# 19    751145000000000000         NaN
# 20    751115000000000000         NaN
# 21    751016000000000000         NaN
# 22    750865000000000000         NaN
# 23    750811000000000000         NaN
# 24    750692000000000000         NaN
# 25    750691000000000000         NaN
# 26    750682000000000000         NaN
# 27    750679000000000000         NaN
# 28    750678000000000000         NaN
# 29    750668000000000000         NaN
# ...                  ...         ...
# 1059  688444000000000000         NaN
# 1060  688428000000000000         NaN
# 1061  688427000000000000         NaN
# 1062  688426000000000000         NaN
# 1063  688426000000000000         NaN
# 1064  688426000000000000         NaN
# 1065  688393000000000000         NaN
# 1066  688356000000000000         NaN
# 1067  688353000000000000         NaN
# 1068  685600000000000000         NaN
# 1069  685591000000000000         NaN
# 1070  685584000000000000         NaN
# 1071  685583000000000000         NaN
# 1072  685572000000000000         NaN
# 1073  685490000000000000         NaN
# 1074  683037000000000000         NaN
# 1075  682805000000000000         NaN
# 1076  682805000000000000         NaN
# 1077  682793000000000000         NaN
# 1078  682765000000000000         NaN
# 1079  680735000000000000         NaN
# 1080  680506000000000000         NaN
# 1081  680504000000000000         NaN
# 1082  680496000000000000    759251.0
# 1083  680492000000000000         NaN
# 1084  678490000000000000         NaN
# 1085  678446000000000000         NaN
# 1086  678442000000000000         NaN
# 1087  676510000000000000         NaN
# 1088  676494000000000000         NaN
#
#                                            statusSource       screenName  \
# id
# 0     <a href="http://twitter.com/download/iphone" r...  realDonaldTrump
# 1     <a href="http://twitter.com/download/iphone" r...  realDonaldTrump
# 2     <a href="http://twitter.com/download/iphone" r...  realDonaldTrump
# 3     <a href="http://twitter.com/download/iphone" r...  realDonaldTrump
# 4     <a href="http://twitter.com/download/iphone" r...  realDonaldTrump
# 5     <a href="http://twitter.com/download/android" ...  realDonaldTrump
# 6     <a href="http://twitter.com/download/android" ...  realDonaldTrump
# 7     <a href="http://twitter.com/download/android" ...  realDonaldTrump
# 8     <a href="http://twitter.com/download/android" ...  realDonaldTrump
# 1082  <a href="http://twitter.com/download/android" ...  realDonaldTrump
# 1083  <a href="http://twitter.com/download/android" ...  realDonaldTrump
# 1084  <a href="http://twitter.com/download/android" ...  realDonaldTrump
# 1085  <a href="http://twitter.com/download/android" ...  realDonaldTrump
# 1086  <a href="http://twitter.com/download/android" ...  realDonaldTrump
# 1087  <a href="http://twitter.com/download/iphone" r...  realDonaldTrump
# 1088  <a href="http://twitter.com/download/iphone" r...  realDonaldTrump
#
#       retweetCount  isRetweet  retweeted  longitude  latitude  label
# id
# 0             5256      False      False        NaN       NaN     -1
# 1             3432      False      False        NaN       NaN     -1
# 2             8810      False      False        NaN       NaN     -1
# 3             9112      False      False        NaN       NaN     -1
# 4             4144      False      False        NaN       NaN     -1
# 5             6564      False      False        NaN       NaN      1
# 6            14520      False      False        NaN       NaN      1
# 7            11975      False      False        NaN       NaN      1
# 8            19030      False      False        NaN       NaN      1
# 9             9147      False      False        NaN       NaN     -1
# 10            5710      False      False        NaN       NaN      1
# 11           14639      False      False        NaN       NaN     -1
# 12           14074      False      False        NaN       NaN     -1
# 13            8989      False      False        NaN       NaN     -1
# 14            7401      False      False        NaN       NaN     -1
# 15           28851      False      False        NaN       NaN      1
# 16           20210      False      False        NaN       NaN      1
# 17            4601      False      False        NaN       NaN     -1
# 18            6593      False      False        NaN       NaN     -1
# 19            3330      False      False        NaN       NaN     -1
# 20            6908      False      False        NaN       NaN      1
# 21            5012      False      False        NaN       NaN     -1
# 22           26442      False      False        NaN       NaN     -1
# 23            9735      False      False        NaN       NaN     -1
# 24            5092      False      False        NaN       NaN      1
# 25            4284      False      False        NaN       NaN      1
# 26            4998      False      False        NaN       NaN      1
# 27            4352      False      False        NaN       NaN      1
# 28            3547      False      False        NaN       NaN      1
# 29           10586      False      False        NaN       NaN      1
# ...            ...        ...        ...        ...       ...    ...
# 1059          3938      False      False        NaN       NaN     -1
# 1060          1892      False      False        NaN       NaN     -1
# 1061          2594      False      False        NaN       NaN     -1
# 1062          2115      False      False        NaN       NaN     -1
# 1063          2151      False      False        NaN       NaN     -1
# 1064          2436      False      False        NaN       NaN     -1
# 1065          2826      False      False        NaN       NaN     -1
# 1066          3602      False      False        NaN       NaN     -1
# 1067          2327      False      False        NaN       NaN      1
# 1068          2448      False      False        NaN       NaN     -1
# 1069          2585      False      False        NaN       NaN     -1
# 1070          2666      False      False        NaN       NaN     -1
# 1071          2184      False      False        NaN       NaN     -1
# 1072          1296      False      False        NaN       NaN     -1
# 1073          1993      False      False        NaN       NaN      1
# 1074           937      False      False        NaN       NaN      1
# 1075          2750      False      False        NaN       NaN      1
# 1076          1961      False      False        NaN       NaN     -1
# 1077          3482      False      False        NaN       NaN     -1
# 1078          3510      False      False        NaN       NaN     -1
# 1079          2889      False      False        NaN       NaN      1
# 1080          5081      False      False        NaN       NaN      1
# 1081          1707      False      False        NaN       NaN      1
# 1082          1365      False      False        NaN       NaN      1
# 1083          1060      False      False        NaN       NaN      1
# 1084           990      False      False        NaN       NaN      1
# 1085          1146      False      False        NaN       NaN      1
# 1086          1151      False      False        NaN       NaN      1
# 1087           713      False      False        NaN       NaN     -1
# 1088           952      False      False        NaN       NaN     -1
#
# [1089 rows x 17 columns]

# %% [markdown]
# <h3> Train and Classify </h3>
#
# <p> Implement <code>train_and_classify</code>. It should extract feature vectors from the given pandas dataframes. Train a model and return the labels of the test data. The feature vectors and models to use are up to you to decide.</p>
#
# <p><b>Your final score will be determined by executing <code>train_and_classify</code> with the provided training set for training and a hidden test set for classification. We will then evaluate the accuracy of your output.</b></p>
# <p><b>NOTE: Please limit your training time to 10 minutes.</b></p>

# %%
def extract_length(df_X_train):
    # the tweets themselves are in the zero-th column. Extract from dataframe
    tweets = df_X_train.iloc[:,0]
    length = tweets.str.len()
    return length

# %%
def split_sentences(string):
    '''
    Splits a tweet on ". " such that sentences are separated from each other.
    Does not split on "." so that periods in URLs are not misunderstood as the end of a sentence
    
    We should add additional characters to split on like exclamation marks and question marks
    '''
    return string.split(". ")

def extract_number_of_sentences(df_X_train):
    tweets = df_X_train.iloc[:,0]
    splitted_tweets = tweets.apply(split_sentences)
    n_sentences = splitted_tweets.apply(len)
    
    return n_sentences

def extract_number_of_characters_per_sentence(df_X_train):    
    def average_characters_per_string(list_of_strings):
        return np.mean(list(map(len,list_of_strings)))

    tweets = df_X_train.iloc[:,0]
    splitted_tweets = tweets.apply(split_sentences)
    n_characters_per_sentence = splitted_tweets.apply(average_characters_per_string)
    
    return n_characters_per_sentence

# %%
#<GRADED>
def train_and_classify(df_X_train, Y_train, df_X_test):
    """
    Extracts features from df_X_train. Train a model
    on training data and training labels (Y_train).
    Predict the labels of df_X_test.
    
    df_X_train : pandas data frame of training data
    Y_train    : numpy array of labels for training data
    df_X_test  : pandas data frame of test data
    
    Output:
    Y_test : numpy array of labels for test data
    """
    
    ## fill in code here
    def extract_feature_vec(df_X):
        # extracts feature vectors
        features = []
        
        features.append(extract_length(df_X))
        features.append(extract_number_of_sentences(df_X))
        features.append(extract_number_of_characters_per_sentence(df_X))
        
        return pd.concat(features, axis=1)
    
    X_train = extract_feature_vec(df_X_train)
    X_test  = extract_feature_vec(df_X_test)
    
    # create and train model (consider doing k-fold cross validation as well)
    clf = svm.SVC()
    clf.fit(X_train, Y_train)
    
    # evaulate model
    Y_test = clf.predict(X_train) 

    return Y_test
#</GRADED>

# %% [markdown]
# <h3> Evaluation</h3>
#
# <p>Below is some code to see your accuracy when trained and tested on the training data set.</p>

# %%
# evalulate and classify on training set
Y_pred = train_and_classify(df_X_train, Y_train, df_X_train)

def accuracy(Y_pred, Y_true):
    return (Y_pred == Y_true).sum() / Y_pred.shape[0]

acc = accuracy(Y_pred, Y_train)
print('accurary: ' + str(round(acc * 100, 2)) + '%')
# Out:
# accurary: 77.78%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
